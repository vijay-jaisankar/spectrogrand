# %%
import numpy as np
import pandas as pd
import os
from glob import glob

# %% [markdown]
# ## Install `imagededup`

# %%
# !pip install imagededup
# Out:
# Requirement already satisfied: imagededup in /opt/conda/lib/python3.10/site-packages (0.3.2)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from imagededup) (2.0.0+cpu)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from imagededup) (0.15.1+cpu)
# Requirement already satisfied: Pillow>=9.0 in /opt/conda/lib/python3.10/site-packages (from imagededup) (9.5.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from imagededup) (4.66.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from imagededup) (1.2.2)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.10/site-packages (from imagededup) (1.4.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from imagededup) (3.7.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imagededup) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imagededup) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imagededup) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imagededup) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imagededup) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imagededup) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imagededup) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->imagededup) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->imagededup) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->imagededup) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->imagededup) (3.2.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->imagededup) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->imagededup) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->imagededup) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->imagededup) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->imagededup) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision->imagededup) (2.31.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->imagededup) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->imagededup) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->imagededup) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->imagededup) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->imagededup) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision->imagededup) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->imagededup) (1.3.0)

# %% [markdown]
# ## Average Hashing

# %%
from imagededup.methods import AHash
hasher = AHash()

# %%
encodings = hasher.encode_images(image_dir='/kaggle/input/mumu-dance-music-album-covers/mumu-image-annotations/album_covers_dance_music')
# Out:
# 2024-01-17 06:54:22,715: INFO Start: Calculating hashes...
# 100%|██████████| 506/506 [00:00<00:00, 930.29it/s]
# 2024-01-17 06:54:23,324: INFO End: Calculating hashes!

# %% [markdown]
# ## Find "duplicates" into Val Split

# %%
duplicates = hasher.find_duplicates_to_remove(encoding_map=encodings)
# Out:
# /opt/conda/lib/python3.10/site-packages/imagededup/methods/hashing.py:317: RuntimeWarning: Parameter num_enc_workers has no effect since encodings are already provided
#   warnings.warn('Parameter num_enc_workers has no effect since encodings are already provided', RuntimeWarning)
# 2024-01-17 06:54:23,332: INFO Start: Evaluating hamming distances for getting duplicates
# 2024-01-17 06:54:23,333: INFO Start: Retrieving duplicates using Cython Brute force algorithm
# 100%|██████████| 506/506 [00:00<00:00, 8302.73it/s]
# 2024-01-17 06:54:23,436: INFO End: Retrieving duplicates using Cython Brute force algorithm
# 2024-01-17 06:54:23,437: INFO End: Evaluating hamming distances for getting duplicates

# %% [markdown]
# ## Split the "non-duplicates" into random Train/Test Splits

# %%
all_images = os.listdir('/kaggle/input/mumu-dance-music-album-covers/mumu-image-annotations/album_covers_dance_music')
unique_images = [f for f in all_images if f not in duplicates]

# %%
import random
random.seed(42)

# %%
train_set = random.sample(unique_images, 256) 
test_set = [f for f in unique_images if f not in train_set]
val_set = duplicates.copy()

# %% [markdown]
# ## Save the details of the splits into individual files

# %%
print(f"Details of the split \n Size of train set: {len(train_set)} \n Size of test set: {len(test_set)} \n Size of val set: {len(val_set)}")
# Out:
# Details of the split
#  Size of train set: 256
#  Size of test set: 172
#  Size of val set: 78

# %%
assert len(set(train_set).intersection(test_set)) == 0
assert len(set(train_set).intersection(val_set)) == 0
assert len(set(test_set).intersection(val_set)) == 0

# %%
with open("/kaggle/working/mumu_a_hash_train.txt", "w") as f:
    for _file in train_set:
        f.write(f"{_file}\n")

# %%
with open("/kaggle/working/mumu_a_hash_test.txt", "w") as f:
    for _file in test_set:
        f.write(f"{_file}\n")

# %%
with open("/kaggle/working/mumu_a_hash_val.txt", "w") as f:
    for _file in val_set:
        f.write(f"{_file}\n")

# %% [markdown]
# ## Load the HouseX Dataset

# %%
import numpy as np 
import pandas as pd 
import os

all_housex_file_paths = []

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        all_housex_file_paths.append(os.path.join(dirname, filename))

# %%
all_housex_file_paths
# Out:
# ['/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/TV Noise - 808.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills - Infinite (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Loopers - I_m Odd.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills - Rewire (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills - RUSH (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Loopers - Feel It.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Blinders _ SWACQ - Side 2 Side (SWACQ Extended Edit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Julian Jordan _ Siks - Juice.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Magnificence _ Seth Hills - Fire.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Julian Jordan - Tell Me The Truth.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Loopers - Drummachine.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills _ Crime Zcene - Echo (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills - Centipede.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Loopers _ Jordan Wayne - Rudeboy (Original Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Mike Cervello _ BeauDamian - Outlast.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills _ AYOR - Instinct (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/TV Noise - Don_t Stop (Explicit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills _ Whats Gud - Pressure (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills _ Crime Zcene - Stardust.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/TV Noise _ Blinders - Fire (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/TV Noise - Astral.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Julian Jordan - Next Level.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Loopers _ SHAIROX - Duality.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills - Rebound (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Blinders - Leaving (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Matisse _ Sadko - Grizzly.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Martin Garrix _ Blinders - Breach (Walk Alone).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Dyro - Hella Dope (Explicit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Aspyer - Slash.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills - Whisper.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Crime Zcene - Lights Out.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Martin Garrix _ Loopers - Game Over.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Martin Garrix _ Julian Jordan _ Tinie Tempah - Diamonds (Explicit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Loopers _ Dyro - I know U.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Magnificence - Closer.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Loopers - Blaze It Up.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Blinders - Relieve (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Loopers _ Seth Hills - Out Of Control (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Dyro - Bring It Down.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Julian Jordan - Oldskool (Explicit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Matisse _ Sadko _ Michel Zitron - Hold On (feat_ Michel Zitron).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Severman _ Alex Aspen _ Revealed Recordings - This Feeling (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Mark Sixma - Million Miles.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Severman _ Hunter Grant _ Arvenius - Fight The Good Fight.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Manse _ Cuebrick _ IIVES - Runaway.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Clinton Kane - Drown (Nicky Romero Remix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Manse _ WildVibes _ Vories - Our Symphony.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/WildVibes _ Patrick Key _ Stine Kristiansen - Love Again.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Matisse _ Sadko - Together.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Reinn _ Daiki Fukasawa - Back To You.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/WildVibes _ Patrick Key _ David Shane - You Are Not Alone.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Manse - No Matter Where We Are (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ DubVision _ Shaun Farrugia - Starlight (Keep Me Afloat).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Tom Swoon - Never Giving Up (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Matisse _ Sadko - Forever.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Kosling _ CHRNS - In Your Head.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Bonn - High On Life.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Trevor Omoto _ Revealed Recordings - Never Let Me Go.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/ARHEX _ HHMR - Eternity.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Warren _ SƠN _ Emelie Cyréus - Moving On Without You.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Christian Burns _ Arston - Where The Lights Are (Original Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Ryos _ Elle Vee - Identity.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/twocolors - Lovefool (Nicky Romero Remix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Khalid - Ocean (DubVision Remix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Radiology _ Skydrops _ Ian Stone - Above The Tide.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/J3RO _ Notbad _ Revealed Recordings _ Cornelia Antonijev - Save Me Now (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Severman _ Glared _ Tom Heming - Feel Young.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Matisse _ Sadko _ John Martin - Won’t Let You Go.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Dash Berlin _ John Dahlbäck _ BullySongs - Never Let You Go (Radio Edit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Aspyer _ Matluck - Somebody To Hold (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Spenz _ Revealed Recordings - Crimes.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/HEVALEN - With My Baby.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Bonn - No Sleep (DubVision Remix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Severman _ Revealed Recordings _ Holly - With My Baby (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Fablers _ Revealed Recordings _ Sam Knight - Need You.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ John Martin - Higher Ground.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Martin Garrix _ Shaun Farrugia - If We_ll Ever Be Remembered.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Arston _ Soul Parker - When We Were Young.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Alex Aspen - Glow (Radio Edit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/progressive house/Thomas Hayes _ Kyler England - Golden (Manse Radio Edit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Melomania.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Itro - Flares.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu _ Itro - Fantasy.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Avicii - Levels (Original Version).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu _ Marcus Mouya - Running Away.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Dogena _ Dripice - Euphoria (Radio Edit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Steerner _ Martell - Blue.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Roots.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Steerner _ Martell - Sun.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Such Fun.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu _ Itro - Cloud 9.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/JJD - Aeon.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Puzzle.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Hope (Original Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Itro - Up.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Janji - Shadows.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Colors.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/HOPE T - Game.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Steerner _ Martell - Crystals.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Candyland pt_ II.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Itro - Phantasm.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/徐梦圆 _ Tobu - Feels.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Noah Stromberg - Colors.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Itro - Times.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Infectious.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Let_s Go.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/A7i - Stay.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Caprev - Flipped.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Vinze - Fantasy.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Mesmerize.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Candyland.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Steerner _ Martell - Sky (Radio Edit).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Steerner - Waves.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Reflection.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Good Times.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Cool.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Dripice - Horizon.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu - Dreams.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Tobu _ Itro - Sunburst.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/melodic house/Itro - Home.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/David Guetta _ Martin Garrix _ Brooks - Like I Do.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Martin Garrix - Oops.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Moti - All The Love You Got (Sofus Wiene Remix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Sofus Wiene - Wanna Know Your Name.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Jay Hardway _ Mesto - Save Me.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Brooks _ Isabèl Usher - Someday.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Martin Garrix _ Mesto - WIEE.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Jay Eskar _ Jesus Ernesto Escarcega - You _ I.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Mo Falk - Nutella.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Mo Falk - Feel So Gud (Original Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Brooks - Make Your Move.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Nairi _ Avetik Terian - More Time.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Trevor Omoto - The Way.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Dropgun _ Bryan Finlay - Tomorrow Never Comes.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Griffyn _ Illenium ft. Daya - Feel Good (Brooks Remix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Brooks - If Only I Could (Original Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Raven _ Kreyn - There For You.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/IZECOLD _ Brooks _ 디아이제이 (D_I_J) - Close (Brooks Remix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Martin Garrix _ Brooks - Byte.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Brooks _ GRX - Boomerang (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Martin Garrix _ Brooks - Quantum.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Jay Eskar - Atlantis.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/MOTi _ Domastic - Bangalore.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Crunkz _ Raphael Pardyak - Never Let Me Go.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Brooks - Pinball (Original Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Nrvos _ VANGUARD RECORDS - Daydream.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Jay Eskar _ Jesus Escarcega - Lucid Dreams.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Brooks - Hold It Down (Extended Mix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Markhese - Aurora.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Mo Falk - Medicine.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Brooks - Lynx.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Brooks _ Gia Koka - Say A Little Prayer.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Trevor Omoto _ Peter Pentsak _ PeTE - Nothing To Hide.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/DEBRIS _ RudeLies _ Jex - Animal.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/NOTD _ kenzie _ Brooks - Worst Thing (Brooks Remix).wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Robin Hustin _ TobiMorrow _ Jex - Light It Up.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/Markhese _ Love Kr3w - Earthquake.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/RetroVision - Waves.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/SeQReP _ Trevor Omoto _ Kasper Smits - Love Got U.wav',
#  '/kaggle/input/housex-dataset/consolidatedrawaudio/future house/R3HAB _ Mike Williams - Lullaby.wav']

# %% [markdown]
# ## Load audio file into np array

# %%
from scipy.io import wavfile
import librosa

def load_audio_file(file_path):
    sr, origin_data = wavfile.read(file_path)
    origin_type = origin_data.dtype
    resampled_data = librosa.resample(origin_data.T.astype('float'), orig_sr = sr, target_sr = 48000) # transpose array to librosa shape and sampling rate of 48000
    resampled_data = librosa.to_mono(resampled_data)        
    resampled_data = resampled_data.T.astype(origin_type) # transpose back to scipy.io.wavfile shape
    data_np = np.array(resampled_data)
    return data_np

# %%
sample_audio_np = load_audio_file('/kaggle/input/housex-dataset/consolidatedrawaudio/bass house/Seth Hills - Infinite (Extended Mix).wav')
print(sample_audio_np.shape)
# Out:
# (9630000,)

# %% [markdown]
# ## Set up CUDA

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Generating Audio Embeddings using `laion/clap-htsat-fused`

# %%
from datasets import load_dataset
from transformers import pipeline
from datasets import load_dataset
from transformers import ClapModel, ClapProcessor
# Out:
# 2024-02-02 07:15:25.515899: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-02 07:15:25.515959: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-02 07:15:25.517907: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
model = ClapModel.from_pretrained("laion/clap-htsat-fused").to(device)
processor = ClapProcessor.from_pretrained("laion/clap-htsat-fused")
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %% [markdown]
# ## Sample Run

# %%
inputs = processor(audios=sample_audio_np, sampling_rate=48000, return_tensors="pt").to(0)
audio_embed = model.get_audio_features(**inputs)
print(audio_embed.shape)
# Out:
# torch.Size([1, 512])

# %%
audio_embed[0].detach().cpu()
# Out:
# tensor([-0.0401,  0.0051, -0.0358,  0.0607,  0.0674,  0.0887,  0.0251, -0.0313,
#         -0.0392, -0.0640, -0.0332,  0.0794, -0.0490, -0.0159, -0.0108, -0.0118,
#          0.0103, -0.0226,  0.0163, -0.0134, -0.0083,  0.0162,  0.0118, -0.0627,
#          0.0371, -0.0049, -0.0395,  0.0911, -0.0186, -0.0123,  0.0943,  0.0052,
#          0.0270,  0.0187,  0.0004,  0.0206, -0.0433,  0.0259, -0.0020,  0.0214,
#         -0.0398,  0.0635,  0.0459,  0.0421, -0.0203,  0.0145, -0.0349, -0.0315,
#          0.0127, -0.0041,  0.0315, -0.1003,  0.0016,  0.0869, -0.0550,  0.0782,
#          0.0194,  0.0015, -0.0600, -0.0121,  0.0633,  0.1018,  0.0075, -0.0325,
#         -0.0366, -0.0156,  0.0259, -0.0367,  0.0284,  0.0525, -0.0338,  0.0618,
#          0.0121,  0.0304, -0.0839, -0.0604,  0.0035,  0.0099, -0.0134,  0.0470,
#          0.0705, -0.0160,  0.0330,  0.0021,  0.0444, -0.0131,  0.0218,  0.0206,
#          0.0045,  0.0197,  0.0156,  0.0606, -0.0305,  0.1190,  0.0166,  0.0115,
#          0.0179,  0.0128,  0.0086, -0.0391,  0.0018,  0.0761,  0.0300, -0.0267,
#          0.0617, -0.0319,  0.0396,  0.0512,  0.0184,  0.0047, -0.0394, -0.0446,
#          0.0089, -0.0368, -0.0333, -0.0237,  0.0456, -0.0292, -0.0933, -0.0187,
#         -0.0516,  0.0034, -0.0344,  0.0853,  0.0368, -0.0605, -0.0566, -0.0075,
#         -0.0002, -0.0490,  0.0546,  0.0084,  0.0973, -0.0018,  0.0087, -0.0632,
#         -0.0933,  0.0227,  0.0700, -0.0148, -0.1084, -0.0284, -0.0828,  0.0605,
#          0.0155, -0.0054,  0.0344,  0.0388,  0.0339,  0.0500,  0.0182, -0.0141,
#         -0.0055, -0.0797,  0.0569, -0.0142, -0.0274,  0.0079, -0.0145,  0.0380,
#         -0.0371,  0.0321, -0.0007,  0.0185, -0.0019,  0.0105, -0.0915,  0.0434,
#          0.0298, -0.0625,  0.0483,  0.0589,  0.0017, -0.0142, -0.0147,  0.0194,
#         -0.0142,  0.0118, -0.0445, -0.0228,  0.0227, -0.0340,  0.0112,  0.0570,
#          0.0011, -0.0493, -0.0762,  0.0301, -0.0139, -0.0284,  0.0525,  0.0702,
#          0.0335, -0.0075,  0.0021,  0.0602, -0.0696,  0.1055, -0.0013, -0.0922,
#          0.0264, -0.0149, -0.0090,  0.0630,  0.0182,  0.0401, -0.0084, -0.0808,
#         -0.0520, -0.0429,  0.1177, -0.1112,  0.0780, -0.0101, -0.0842,  0.0058,
#         -0.0647,  0.0136,  0.0080,  0.0658, -0.0892,  0.0091, -0.0087, -0.0026,
#         -0.0361,  0.0243, -0.0533, -0.0233,  0.0953, -0.0436, -0.0162, -0.0089,
#          0.0184, -0.0067,  0.0215,  0.0123, -0.0473, -0.0423,  0.0265,  0.0125,
#          0.0593, -0.0769, -0.0079,  0.0406, -0.0364,  0.0643,  0.0395,  0.0706,
#          0.0152, -0.0231, -0.0336, -0.0436, -0.0642, -0.0163, -0.0222,  0.0101,
#         -0.0164,  0.0058, -0.0146, -0.0792, -0.0610, -0.0029, -0.0237, -0.0271,
#          0.0188, -0.0579, -0.0561,  0.0442,  0.1317, -0.0468,  0.0385, -0.0328,
#         -0.0546, -0.0139, -0.0608, -0.0195,  0.0411, -0.0156,  0.0144, -0.0334,
#         -0.0087,  0.0627, -0.0647, -0.0166,  0.0436, -0.0580, -0.0758,  0.0149,
#         -0.0065, -0.0348,  0.0932,  0.0922,  0.0059,  0.0546, -0.0733,  0.0731,
#         -0.0083,  0.0411, -0.0255,  0.0195, -0.0675,  0.0682,  0.0486, -0.0624,
#          0.0077,  0.0267,  0.0088,  0.0479,  0.0350,  0.0129, -0.0050, -0.0451,
#         -0.0317, -0.0384, -0.0270,  0.0214,  0.0325,  0.0007,  0.0420,  0.0632,
#          0.0820, -0.0908,  0.0174,  0.0666, -0.0644,  0.0017,  0.0100,  0.0451,
#         -0.0249,  0.0250, -0.0124, -0.0633,  0.0291,  0.0006, -0.0785, -0.0213,
#          0.0104,  0.0687, -0.0267,  0.0033, -0.0622, -0.0193, -0.0362,  0.0378,
#         -0.0041, -0.0649, -0.0146,  0.0257, -0.0110,  0.0370,  0.0272,  0.0056,
#         -0.0216, -0.0207, -0.0705,  0.0779, -0.0370,  0.0260,  0.0744, -0.0217,
#          0.0411,  0.0078,  0.0287,  0.0710,  0.0060,  0.0720, -0.0023,  0.0609,
#          0.0291, -0.0461, -0.0050, -0.0003,  0.0010, -0.0090,  0.0250,  0.0358,
#          0.0616, -0.0104,  0.0031,  0.0312, -0.1249,  0.0123,  0.0455,  0.0414,
#          0.0124, -0.0464, -0.0245,  0.0031, -0.0321, -0.0167,  0.0004, -0.0290,
#         -0.0221, -0.0225, -0.0602,  0.0147, -0.0811, -0.0530,  0.0339,  0.0201,
#         -0.0326,  0.0627,  0.0407,  0.0114,  0.0029,  0.0446,  0.0466,  0.0562,
#         -0.0394, -0.0340,  0.0102,  0.0134, -0.0226, -0.1041,  0.0126, -0.0031,
#         -0.1006,  0.0311,  0.0204,  0.0230,  0.0201,  0.0703,  0.0127, -0.0717,
#         -0.0887, -0.0021,  0.0219, -0.0039,  0.0689, -0.0089,  0.0338, -0.0749,
#         -0.0372,  0.0405,  0.0324,  0.0259,  0.1051,  0.0368,  0.0156,  0.0512,
#         -0.0643,  0.0182, -0.0243,  0.0523,  0.0114, -0.0429, -0.0098,  0.0232,
#         -0.0136,  0.0100, -0.0273, -0.0071, -0.0167,  0.0155, -0.0501, -0.0097,
#         -0.0389, -0.0735, -0.0008,  0.0340, -0.0463,  0.0371,  0.0153,  0.0184,
#         -0.0084,  0.0134,  0.0314,  0.0042, -0.0120, -0.0337, -0.0169,  0.0542,
#         -0.0438,  0.0115, -0.0586, -0.0684,  0.0267, -0.0008, -0.0061, -0.0342,
#         -0.0278,  0.0507, -0.0504, -0.0730,  0.0595,  0.0323,  0.0432,  0.0065,
#         -0.0479, -0.0374, -0.0050, -0.0304, -0.0082,  0.0706,  0.0336, -0.0072,
#          0.0154,  0.0055, -0.0652, -0.0569,  0.0253, -0.0003,  0.0361, -0.0725,
#          0.0008,  0.0493, -0.0173, -0.0044,  0.0339,  0.0340, -0.0007, -0.0767])

# %% [markdown]
# ## Collate and save embeddings for all songs

# %%
from tqdm import tqdm

all_housex_embeddings_dict = {}
N = len(all_housex_file_paths)

for i in tqdm(range(N)):
    # Get audio features
    audio_file_name = all_housex_file_paths[i]
    audio_genre = audio_file_name.split("/")[-2].replace(" ", "_")
    audio_inputs_np = load_audio_file(file_path = audio_file_name)
    
    # Construct inputs to CLAP model
    clap_inputs = processor(audios=audio_inputs_np, sampling_rate=48000, return_tensors="pt").to(device)
    
    # Get embeddings from CLAP model
    clap_outputs = model.get_audio_features(**clap_inputs)
    
    # Store the detached embeddings
    audio_embeds = clap_outputs[0].detach().cpu()
    
    # Insert into the main dictionary
    if audio_genre not in all_housex_embeddings_dict:
        all_housex_embeddings_dict[audio_genre] = []
    
    all_housex_embeddings_dict[audio_genre].append(audio_embeds)
# Out:
# 100%|██████████| 160/160 [04:31<00:00,  1.70s/it]

# %%
import pickle

with open("/kaggle/working/clap_fused_housex_saved_embeds_dict.pkl", "wb") as f:
    pickle.dump(all_housex_embeddings_dict, f)

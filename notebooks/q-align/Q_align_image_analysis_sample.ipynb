# %% [markdown]
# ## Imports and Installations

# %%
# !pip install --upgrade sentencepiece icecream accelerate transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 16.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
# ...

# %% [markdown]
# ## Load model
#
# - Note: Restart the notebook after installations

# %%
import requests
import torch
from transformers import AutoModelForCausalLM

model = AutoModelForCausalLM.from_pretrained("q-future/one-align", trust_remote_code=True,
                                             torch_dtype=torch.float16, device_map="auto")
# Out:
# Instantiating LlamaAttention without passing `layer_idx` is not recommended and will to errors during the forward call, if caching is used. Please make sure to provide a `layer_idx` when creating this class.
# tokenizer_config.json:   0%|          | 0.00/749 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/438 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/317 [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/162 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Inference for Sample Image
#
# - Ref: [Model Zoo](https://github.com/Q-Future/Q-Align/tree/main/model_zoo)

# %% [markdown]
# ### Image Quality Assessment

# %%
from PIL import Image
model.score([Image.open(requests.get("https://raw.githubusercontent.com/Q-Future/Q-Align/main/fig/singapore_flyer.jpg",
                                     stream=True).raw)], task_="quality", input_="image") # task_ : quality | aesthetics; # input_: image | video
# Out:
# tensor([1.8506], device='cuda:0')

# %% [markdown]
# ### Image Aesthetics Assessment

# %%
from PIL import Image
model.score([Image.open(requests.get("https://raw.githubusercontent.com/Q-Future/Q-Align/main/fig/singapore_flyer.jpg",
                                     stream=True).raw)], task_="aesthetics", input_="image") # task_ : quality | aesthetics; # input_: image | video
# Out:
# tensor([2.2617], device='cuda:0')

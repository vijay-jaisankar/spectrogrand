# %%
import numpy as np
import pandas as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Clone the customised repo locally

# %%
# !git clone https://github.com/vijay-jaisankar/HouseX.git
# Out:
# Cloning into 'HouseX'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 230 (delta 67), reused 115 (delta 64), pack-reused 112
# Receiving objects: 100% (230/230), 84.75 KiB | 7.70 MiB/s, done.
# Resolving deltas: 100% (132/132), done.

# %% [markdown]
# ## Install the dependencies

# %%
# %cd /kaggle/working/HouseX
# Out:
# /kaggle/working/HouseX

# %%
# !cat requirements.txt
# Out:
# librosa
# matplotlib
# numpy
# Pillow
# pygame
# scikit_learn
# scipy
# SoundFile
# tqdm
# Unidecode
# vit-pytorch
# numba
# tensorboard

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 82.3 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 2.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Set the parameters for testing the training procedure

# %%
N_EPOCHS = 30
DATA_DIR = "/kaggle/input/housex-spectrograms/melspecgrams_data"
TASK_ID = 1 # Resnet-18

# %% [markdown]
# ## Train the model

# %%
# !ls
# Out:
# LICENSE    infer.py   metadata	requirements.txt  vis_emb.py
# README.md  logger.py  plot.py	train.py

# %%
command_string = f"python train.py --id {TASK_ID} --do_train --pretrained --epochs {N_EPOCHS} --data_dir {DATA_DIR}"

# %%
print(f"Training command: {command_string}")
# Out:
# Training command: python train.py --id 1 --do_train --pretrained --epochs 30 --data_dir /kaggle/input/housex-spectrograms/melspecgrams_data

# %%
# !{command_string}
# Out:
# 2024-02-24 10:28:06.862173: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-24 10:28:06.862300: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-24 10:28:06.979446: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Namespace(dropout=0.5, epochs=30, lr=0.002, id=1, metric='weighted', pretrained=True, do_train=True, data_dir='/kaggle/input/housex-spectrograms/melspecgrams_data')
# Running on: Tesla P100-PCIE-16GB
# ...

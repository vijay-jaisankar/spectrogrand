# %%
import numpy as np
import pandas as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Clone the customised repo locally

# %%
# !git clone --quiet https://github.com/vijay-jaisankar/HouseX.git

# %% [markdown]
# ## Install the dependencies

# %%
# %cd /kaggle/working/HouseX/
# Out:
# /kaggle/working/HouseX

# %%
# !cat requirements.txt
# Out:
# librosa
# matplotlib
# numpy
# Pillow
# pygame
# scikit_learn
# scipy
# SoundFile
# tqdm
# Unidecode
# vit-pytorch
# numba
# tensorboard

# %%
# !pip install -q -r requirements.txt

# %% [markdown]
# ## Set the parameters for the training procedure

# %%
N_EPOCHS = 20 # Number of epochs to train for
DATA_DIR = "/kaggle/input/housex-spectrograms/melspecgrams_data" # Parent path of the HouseX spectrograms
TASK_ID =  8 # Resenet-101
BATCH_SIZE = 4 # Batch size of the datasets
NETWORK_VERSION = 'legacy' # Use the new model architecture
TRANSFORMS_VERSION = 'experimental' # Use the new dataset transforms

# %% [markdown]
# ## Train the model - Experimental Transforms

# %%
# !ls
# Out:
# LICENSE    infer.py   metadata	requirements.txt  vis_emb.py
# README.md  logger.py  plot.py	train.py

# %%
command_string = f"python train.py --id {TASK_ID} --do_train --pretrained --epochs {N_EPOCHS} --data_dir {DATA_DIR} --batch_size {BATCH_SIZE} --network_version {NETWORK_VERSION} --transforms_version {TRANSFORMS_VERSION}"

# %%
print(f"Training command: {command_string}")
# Out:
# Training command: python train.py --id 8 --do_train --pretrained --epochs 20 --data_dir /kaggle/input/housex-spectrograms/melspecgrams_data --batch_size 4 --network_version legacy --transforms_version experimental

# %%
# !{command_string}
# Out:
# 2024-02-29 09:37:58.766605: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-29 09:37:58.766702: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-29 09:37:58.873553: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Namespace(dropout=0.5, epochs=20, lr=0.002, id=8, metric='weighted', pretrained=True, do_train=True, data_dir='/kaggle/input/housex-spectrograms/melspecgrams_data', batch_size=4, network_version='legacy', transforms_version='experimental')
# Running on: Tesla P100-PCIE-16GB
# ...

# %% [markdown]
# ## Train the model - Legacy Transforms

# %%
N_EPOCHS = 20 # Number of epochs to train for
DATA_DIR = "/kaggle/input/housex-spectrograms/melspecgrams_data" # Parent path of the HouseX spectrograms
TASK_ID =  8 # Resenet-101
BATCH_SIZE = 4 # Batch size of the datasets
NETWORK_VERSION = 'legacy' # Use the new model architecture
TRANSFORMS_VERSION = 'legacy' # Use the new dataset transforms

# %%
command_string = f"python train.py --id {TASK_ID} --do_train --pretrained --epochs {N_EPOCHS} --data_dir {DATA_DIR} --batch_size {BATCH_SIZE} --network_version {NETWORK_VERSION} --transforms_version {TRANSFORMS_VERSION}"

# %%
# !{command_string}
# Out:
# 2024-02-29 10:00:22.614769: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-29 10:00:22.614834: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-29 10:00:22.616318: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Namespace(dropout=0.5, epochs=20, lr=0.002, id=8, metric='weighted', pretrained=True, do_train=True, data_dir='/kaggle/input/housex-spectrograms/melspecgrams_data', batch_size=4, network_version='legacy', transforms_version='legacy')
# Running on: Tesla P100-PCIE-16GB
# ...
